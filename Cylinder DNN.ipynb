# %% [markdown]
# Create a neural network that is capable of finding the volume of a cylinder given the radius of its base (r) and its height (h). Assume that the radius and height of the cylinder are both in the range 0.5 to 2.0. Simulate the necessary training dataset.
#
# The input features will be radius and height and the label will be $\pi r^2 h$

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import shutil
import math

# %%
# create datasets: train, validation, test
df_train = pd.DataFrame(1.5 * np.random.random_sample((10000,2)) + 0.5, 
            columns = ['radius','height'])

df_valid = pd.DataFrame(1.5 * np.random.random_sample((1000,2)) + 0.5, 
            columns = ['radius','height'])

df_test = pd.DataFrame(1.5 * np.random.random_sample((1000,2)) + 0.5, 
            columns = ['radius','height'])

# %%
# Calculate and append volume to datasets

# training data
labels = []
for index, row in df_train.iterrows():
  volume = math.pi * row['radius']**2 * row['height']
  labels.append(volume)
df_train.insert(0, 'volume', labels, True)

# validation data
labels.clear()
for index, row in df_valid.iterrows():
  volume = math.pi * row['radius']**2 * row['height']
  labels.append(volume)
df_valid.insert(0, 'volume', labels, True)

# test data
labels.clear()
for index, row in df_test.iterrows():
  volume = math.pi * row['radius']**2 * row['height']
  labels.append(volume)
df_test.insert(0, 'volume', labels, True)

# %%
# make input function

def make_input_fn(df, num_epochs):
  return tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    num_epochs = num_epochs,
    shuffle = True,
    queue_capacity = 1000,
    num_threads = 1
  )

# %%
# make prediction function

def make_prediction_input_fn(df, num_epochs):
  return tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = None,
    batch_size = 128,
    num_epochs = num_epochs,
    shuffle = False,            # shuffle = False so we can compare predictions with actual
    queue_capacity = 1000,
    num_threads = 1
  )

# %%
# make feature columns function

DF_COLUMNS = ['volume','radius', 'height']
FEATURES = DF_COLUMNS[1:len(DF_COLUMNS)]
LABEL = DF_COLUMNS[0]

def make_feature_cols():
    input_cols = [tf.feature_column.numeric_column(i) for i in FEATURES]
    return input_cols

# %%
# method for determining RMSE

def print_rmse (model, name, df):
  metrics = model.evaluate(input_fn = make_input_fn(df, 1))
  print('RMSE on {} dataset = {}'.format(name, np.sqrt(metrics['average_loss'])))

# %%
# set directory for trained model, instantiate model, and train model

OUTDIR = 'cylinder_trained'


# for debugging purposes
tf.logging.set_verbosity(tf.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True)


# instantiate model
model = tf.estimator.DNNRegressor(
  hidden_units = [32, 8, 2],
  feature_columns = make_feature_cols(),
  model_dir = OUTDIR)


# train model
model.train(input_fn = make_input_fn(df_train, num_epochs = 100))

print_rmse(model, 'validation', df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'cylinder_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x117505f60>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into cylinder_trained/model.ckpt.
# INFO:tensorflow:loss = 9057.927, step = 1
# INFO:tensorflow:global_step/sec: 443.157
# INFO:tensorflow:loss = 476.0261, step = 101 (0.229 sec)
# INFO:tensorflow:global_step/sec: 527.176
# INFO:tensorflow:loss = 127.00804, step = 201 (0.191 sec)
# INFO:tensorflow:global_step/sec: 576.9
# INFO:tensorflow:loss = 62.74041, step = 301 (0.172 sec)
# INFO:tensorflow:global_step/sec: 615.651
# INFO:tensorflow:loss = 41.812912, step = 401 (0.162 sec)
# INFO:tensorflow:global_step/sec: 609.136
# INFO:tensorflow:loss = 26.556133, step = 501 (0.165 sec)
# INFO:tensorflow:global_step/sec: 604.533
# INFO:tensorflow:loss = 19.958239, step = 601 (0.165 sec)
# INFO:tensorflow:global_step/sec: 610.024
# INFO:tensorflow:loss = 18.964928, step = 701 (0.164 sec)
# INFO:tensorflow:global_step/sec: 615.138
# INFO:tensorflow:loss = 12.958002, step = 801 (0.162 sec)
# INFO:tensorflow:global_step/sec: 629.522
# INFO:tensorflow:loss = 12.668472, step = 901 (0.159 sec)
# INFO:tensorflow:global_step/sec: 601.948
# INFO:tensorflow:loss = 10.221757, step = 1001 (0.167 sec)
# INFO:tensorflow:global_step/sec: 594.39
# INFO:tensorflow:loss = 6.4934425, step = 1101 (0.168 sec)
# INFO:tensorflow:global_step/sec: 563.898
# INFO:tensorflow:loss = 8.3784075, step = 1201 (0.180 sec)
# INFO:tensorflow:global_step/sec: 541.106
# INFO:tensorflow:loss = 8.072998, step = 1301 (0.182 sec)
# INFO:tensorflow:global_step/sec: 565.921
# INFO:tensorflow:loss = 6.147175, step = 1401 (0.177 sec)
# INFO:tensorflow:global_step/sec: 621.392
# INFO:tensorflow:loss = 6.5168467, step = 1501 (0.164 sec)
# INFO:tensorflow:global_step/sec: 612.478
# INFO:tensorflow:loss = 8.680715, step = 1601 (0.162 sec)
# INFO:tensorflow:global_step/sec: 634.9
# INFO:tensorflow:loss = 5.955174, step = 1701 (0.157 sec)
# INFO:tensorflow:global_step/sec: 598.18
# INFO:tensorflow:loss = 3.7802198, step = 1801 (0.167 sec)
# INFO:tensorflow:global_step/sec: 606.898
# INFO:tensorflow:loss = 4.7356243, step = 1901 (0.165 sec)
# INFO:tensorflow:global_step/sec: 554.81
# INFO:tensorflow:loss = 4.2445984, step = 2001 (0.180 sec)
# INFO:tensorflow:global_step/sec: 557.821
# INFO:tensorflow:loss = 4.864455, step = 2101 (0.180 sec)
# INFO:tensorflow:global_step/sec: 601.826
# INFO:tensorflow:loss = 4.2226586, step = 2201 (0.166 sec)
# INFO:tensorflow:global_step/sec: 607.117
# INFO:tensorflow:loss = 3.005884, step = 2301 (0.165 sec)
# INFO:tensorflow:global_step/sec: 618.533
# INFO:tensorflow:loss = 3.0455103, step = 2401 (0.163 sec)
# INFO:tensorflow:global_step/sec: 612.951
# INFO:tensorflow:loss = 2.614095, step = 2501 (0.164 sec)
# INFO:tensorflow:global_step/sec: 617.421
# INFO:tensorflow:loss = 3.3051608, step = 2601 (0.161 sec)
# INFO:tensorflow:global_step/sec: 614.654
# INFO:tensorflow:loss = 2.4076567, step = 2701 (0.164 sec)
# INFO:tensorflow:global_step/sec: 608.729
# INFO:tensorflow:loss = 2.3934407, step = 2801 (0.163 sec)
# INFO:tensorflow:global_step/sec: 604.255
# INFO:tensorflow:loss = 3.2244668, step = 2901 (0.166 sec)
# INFO:tensorflow:global_step/sec: 608.788
# INFO:tensorflow:loss = 2.2907715, step = 3001 (0.163 sec)
# INFO:tensorflow:global_step/sec: 645.843
# INFO:tensorflow:loss = 2.455863, step = 3101 (0.155 sec)
# INFO:tensorflow:global_step/sec: 615.545
# INFO:tensorflow:loss = 2.755898, step = 3201 (0.163 sec)
# INFO:tensorflow:global_step/sec: 613.821
# INFO:tensorflow:loss = 2.970273, step = 3301 (0.162 sec)
# INFO:tensorflow:global_step/sec: 618.87
# INFO:tensorflow:loss = 2.6455774, step = 3401 (0.162 sec)
# INFO:tensorflow:global_step/sec: 621.175
# INFO:tensorflow:loss = 3.465496, step = 3501 (0.161 sec)
# INFO:tensorflow:global_step/sec: 623.842
# INFO:tensorflow:loss = 2.0437744, step = 3601 (0.161 sec)
# INFO:tensorflow:global_step/sec: 584.85
# INFO:tensorflow:loss = 2.296164, step = 3701 (0.170 sec)
# INFO:tensorflow:global_step/sec: 623.43
# INFO:tensorflow:loss = 1.8408132, step = 3801 (0.163 sec)
# INFO:tensorflow:global_step/sec: 627.172
# INFO:tensorflow:loss = 1.7889504, step = 3901 (0.158 sec)
# INFO:tensorflow:global_step/sec: 627.387
# INFO:tensorflow:loss = 1.5117236, step = 4001 (0.160 sec)
# INFO:tensorflow:global_step/sec: 611.902
# INFO:tensorflow:loss = 2.2006674, step = 4101 (0.163 sec)
# INFO:tensorflow:global_step/sec: 617.38
# INFO:tensorflow:loss = 2.1863923, step = 4201 (0.162 sec)
# INFO:tensorflow:global_step/sec: 619.325
# INFO:tensorflow:loss = 1.9189081, step = 4301 (0.162 sec)
# INFO:tensorflow:global_step/sec: 612.175
# INFO:tensorflow:loss = 1.9204341, step = 4401 (0.163 sec)
# INFO:tensorflow:global_step/sec: 606.681
# INFO:tensorflow:loss = 1.8590393, step = 4501 (0.164 sec)
# INFO:tensorflow:global_step/sec: 617.689
# INFO:tensorflow:loss = 1.4619104, step = 4601 (0.163 sec)
# INFO:tensorflow:global_step/sec: 578.667
# INFO:tensorflow:loss = 1.693116, step = 4701 (0.173 sec)
# INFO:tensorflow:global_step/sec: 610.131
# INFO:tensorflow:loss = 1.9843485, step = 4801 (0.164 sec)
# INFO:tensorflow:global_step/sec: 629.323
# INFO:tensorflow:loss = 1.7122979, step = 4901 (0.159 sec)
# INFO:tensorflow:global_step/sec: 616.102
# INFO:tensorflow:loss = 2.0311062, step = 5001 (0.161 sec)
# INFO:tensorflow:global_step/sec: 612.19
# INFO:tensorflow:loss = 1.4461782, step = 5101 (0.164 sec)
# INFO:tensorflow:global_step/sec: 620.321
# INFO:tensorflow:loss = 1.9412419, step = 5201 (0.161 sec)
# INFO:tensorflow:global_step/sec: 610.664
# INFO:tensorflow:loss = 1.490031, step = 5301 (0.164 sec)
# INFO:tensorflow:global_step/sec: 607.751
# INFO:tensorflow:loss = 1.6666245, step = 5401 (0.165 sec)
# INFO:tensorflow:global_step/sec: 613.979
# INFO:tensorflow:loss = 1.3964518, step = 5501 (0.164 sec)
# INFO:tensorflow:global_step/sec: 614.496
# INFO:tensorflow:loss = 2.03618, step = 5601 (0.162 sec)
# INFO:tensorflow:global_step/sec: 617.917
# INFO:tensorflow:loss = 1.8959392, step = 5701 (0.163 sec)
# INFO:tensorflow:global_step/sec: 620.17
# INFO:tensorflow:loss = 1.7504696, step = 5801 (0.161 sec)
# INFO:tensorflow:global_step/sec: 623.885
# INFO:tensorflow:loss = 1.5520699, step = 5901 (0.160 sec)
# INFO:tensorflow:global_step/sec: 609.622
# INFO:tensorflow:loss = 1.6558362, step = 6001 (0.164 sec)
# INFO:tensorflow:global_step/sec: 610.065
# INFO:tensorflow:loss = 1.5051557, step = 6101 (0.163 sec)
# INFO:tensorflow:global_step/sec: 608.651
# INFO:tensorflow:loss = 2.0334673, step = 6201 (0.164 sec)
# INFO:tensorflow:global_step/sec: 585.936
# INFO:tensorflow:loss = 1.3083961, step = 6301 (0.171 sec)
# INFO:tensorflow:global_step/sec: 611.977
# INFO:tensorflow:loss = 1.650148, step = 6401 (0.163 sec)
# INFO:tensorflow:global_step/sec: 614.809
# INFO:tensorflow:loss = 1.7721429, step = 6501 (0.163 sec)
# INFO:tensorflow:global_step/sec: 605.94
# INFO:tensorflow:loss = 1.6738417, step = 6601 (0.165 sec)
# INFO:tensorflow:global_step/sec: 608.595
# INFO:tensorflow:loss = 1.7535827, step = 6701 (0.165 sec)
# INFO:tensorflow:global_step/sec: 620.563
# INFO:tensorflow:loss = 1.9285126, step = 6801 (0.160 sec)
# INFO:tensorflow:global_step/sec: 558.313
# INFO:tensorflow:loss = 1.7613943, step = 6901 (0.180 sec)
# INFO:tensorflow:global_step/sec: 579.919
# INFO:tensorflow:loss = 1.8233196, step = 7001 (0.172 sec)
# INFO:tensorflow:global_step/sec: 619.102
# INFO:tensorflow:loss = 1.7073079, step = 7101 (0.161 sec)
# INFO:tensorflow:global_step/sec: 603.465
# INFO:tensorflow:loss = 1.1808615, step = 7201 (0.166 sec)
# INFO:tensorflow:global_step/sec: 623.351
# INFO:tensorflow:loss = 1.7167728, step = 7301 (0.160 sec)
# INFO:tensorflow:global_step/sec: 622.282
# INFO:tensorflow:loss = 1.6771419, step = 7401 (0.161 sec)
# INFO:tensorflow:global_step/sec: 626.084
# INFO:tensorflow:loss = 1.2469071, step = 7501 (0.159 sec)
# INFO:tensorflow:global_step/sec: 632.604
# INFO:tensorflow:loss = 1.4097581, step = 7601 (0.159 sec)
# INFO:tensorflow:global_step/sec: 633.982
# INFO:tensorflow:loss = 1.5113006, step = 7701 (0.158 sec)
# INFO:tensorflow:global_step/sec: 632.091
# INFO:tensorflow:loss = 1.9940252, step = 7801 (0.158 sec)
# INFO:tensorflow:Saving checkpoints for 7813 into cylinder_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0455253.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-29-19:46:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cylinder_trained/model.ckpt-7813
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-29-19:46:16
# INFO:tensorflow:Saving dict for global step 7813: average_loss = 0.012683058, global_step = 7813, loss = 1.5853822
# RMSE on validation dataset = 0.11261908710002899

# %%
# create predictions generator

predictions = model.predict(input_fn = make_prediction_input_fn(df_valid, 1))

# %%
# print first 20 entries from the validation set with their actual volume and predicted volume

for index, row in df_valid.iterrows():
    r = row['radius']
    h = row['height']
    v = math.pi * r**2 * h
    raw = next(predictions)
    p = raw['predictions'][0]
    d = abs(((p-v)/v) * 100)
    
    print("\nCylinder ",index+1)
    print("radius     = {0:.3f}\nheight     = {1:.3f}\nvolume "
                "    = {2:.3f}\nprediction = {3:.3f}\ndifference = {4:.3f}%".format(r,h,v,p,d))
    if index == 19:
        break
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cylinder_trained/model.ckpt-7813
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Cylinder  1
# radius     = 1.270
# height     = 0.926
# volume     = 4.693
# prediction = 4.694
# difference = 0.028%
#
# Cylinder  2
# radius     = 1.688
# height     = 1.955
# volume     = 17.498
# prediction = 17.581
# difference = 0.474%
#
# Cylinder  3
# radius     = 0.937
# height     = 1.337
# volume     = 3.689
# prediction = 3.796
# difference = 2.880%
#
# Cylinder  4
# radius     = 0.576
# height     = 1.806
# volume     = 1.881
# prediction = 1.981
# difference = 5.322%
#
# Cylinder  5
# radius     = 1.286
# height     = 0.807
# volume     = 4.195
# prediction = 4.289
# difference = 2.236%
#
# Cylinder  6
# radius     = 0.537
# height     = 1.658
# volume     = 1.504
# prediction = 1.580
# difference = 5.072%
#
# Cylinder  7
# radius     = 1.957
# height     = 1.988
# volume     = 23.928
# prediction = 23.478
# difference = 1.878%
#
# Cylinder  8
# radius     = 0.705
# height     = 1.058
# volume     = 1.651
# prediction = 1.741
# difference = 5.420%
#
# Cylinder  9
# radius     = 0.968
# height     = 1.868
# volume     = 5.501
# prediction = 5.584
# difference = 1.506%
#
# Cylinder  10
# radius     = 0.571
# height     = 1.115
# volume     = 1.141
# prediction = 1.073
# difference = 5.955%
#
# Cylinder  11
# radius     = 1.231
# height     = 0.589
# volume     = 2.804
# prediction = 2.796
# difference = 0.276%
#
# Cylinder  12
# radius     = 1.531
# height     = 0.729
# volume     = 5.369
# prediction = 5.256
# difference = 2.101%
#
# Cylinder  13
# radius     = 1.830
# height     = 0.963
# volume     = 10.134
# prediction = 10.075
# difference = 0.582%
#
# Cylinder  14
# radius     = 0.831
# height     = 1.103
# volume     = 2.393
# prediction = 2.495
# difference = 4.268%
#
# Cylinder  15
# radius     = 1.201
# height     = 1.596
# volume     = 7.230
# prediction = 7.283
# difference = 0.728%
#
# Cylinder  16
# radius     = 0.686
# height     = 1.754
# volume     = 2.591
# prediction = 2.522
# difference = 2.661%
#
# Cylinder  17
# radius     = 1.238
# height     = 1.989
# volume     = 9.576
# prediction = 9.336
# difference = 2.506%
#
# Cylinder  18
# radius     = 1.831
# height     = 0.896
# volume     = 9.437
# prediction = 9.370
# difference = 0.702%
#
# Cylinder  19
# radius     = 1.293
# height     = 1.087
# volume     = 5.705
# prediction = 5.618
# difference = 1.520%
#
# Cylinder  20
# radius     = 1.170
# height     = 1.192
# volume     = 5.122
# prediction = 5.101
# difference = 0.400%
